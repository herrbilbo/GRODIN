# %%
#!L
import warnings
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.optim 
import torch.nn.functional as F
import torchvision.datasets as datasets 
import torchvision.transforms as transforms   
import torchvision.models as models

import numpy as np

# %%
#!L
import code

import importlib
importlib.reload(code)
# Out:
# <module 'code' from '/home/jupyter/work/resources/code.py'>

# %%
#!L
seed = 228
torch.manual_seed(seed)
np.random.seed(seed)
torch.cuda.manual_seed(seed)

dataset = 'imagenet-r'
experiment_name = 'd161_ir_msp'

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

net = models.densenet161(pretrained=True).to(device)
# net = models.resnet18(pretrained=True).to(device)

#net = models.resnet50(pretrained=False).to(device)
#net.load_state_dict(torch.load('re0.pth'))

net.eval()
filename = 'EXPERIMENT-43.txt'

params = {'test_ratio_in' : 0.99}

if dataset == 'imagenet-o':
    params['test_ratio_out'] = 0.75
if dataset == 'imagenet-r':
    params['test_ratio_out'] = 0.98333333

information = f''

in_loader_test, out_loader_test, in_loader_gridsearch, out_loader_gridsearch = code.get_data_gridsearch(params, in_path='data', out_path=f'./{dataset}', filename=filename)

print('Done!')
# Out:
# cuda
# Inlier dataset total length: 50000
# Outlier dataset total length: 30000
# Inlier dataset test length: 49500
# Outlier dataset test length: 29499
# Inlier dataset gridsearch length: 500
# Outlier dataset gridsearch length: 501
# Validation:
# inlier test first 10 indices: [3476, 21289, 43731, 42751, 44948, 44513, 29319, 4412, 25411, 26328]
# outlier test first 10 indices: [19096, 29452, 24292, 18449, 4756, 15952, 779, 4210, 28027, 26041]
# inlier gridsearch first 10 indices: [13685, 37855, 16426, 30378, 11578, 36179, 18448, 7856, 21234, 34914]
# outlier gridsearch first 10 indices: [26909, 11369, 27349, 2666, 2210, 16218, 9449, 29350, 15128, 26106]
# Done!

# %%
#!L
# inlier test first 10 indices: [3476, 21289, 43731, 42751, 44948, 44513, 29319, 4412, 25411, 26328]
# outlier test first 10 indices: [1627, 58, 909, 146, 1697, 1590, 1954, 1844, 1604, 0]
# inlier gridsearch first 10 indices: [13685, 37855, 16426, 30378, 11578, 36179, 18448, 7856, 21234, 34914]
# outlier gridsearch first 10 indices: [1408, 1487, 231, 1525, 983, 654, 361, 1825, 924, 619]

# %%
#!L
# %%time

#eps, temper = code.gridsearch_odin(in_loader_gridsearch, out_loader_gridsearch, net, device, filename, information)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.63 µs

# %%
#!L
#print(eps, temper)

# %%
#!L
# code.check_accuracy(in_loader_test, net, device)

# %%
#!L
# %%time
in_norms = code.baseline(in_loader_test, net, device)
code.get_stats(in_norms, 'inliers:')

out_norms = code.baseline(out_loader_test, net, device)
code.get_stats(out_norms, 'outliers:')
# Out:
# current iter: 0
# current iter: 5000
# current iter: 10000
# current iter: 15000
# current iter: 20000
# current iter: 25000
# current iter: 30000
# current iter: 35000
# current iter: 40000
# current iter: 45000
# min = -1.0
# max = -0.0233608391135931
# median = -0.9565990567207336
# mean = -0.827847946327556
# std = 0.22859544105405935
# current iter: 0
# current iter: 5000
# current iter: 10000
# current iter: 15000
# current iter: 20000
# current iter: 25000
# min = -1.0
# max = -0.019476760178804398
# median = -0.5175597071647644
# mean = -0.5516221819795238
# std = 0.2880453064813116
# CPU times: user 1h 3min 22s, sys: 2min, total: 1h 5min 22s
# Wall time: 1h 2min 48s

# %%
#!L
# code.compare_histograms(in_norms, out_norms, in_name='imagenet', out_name=f'{dataset}', filename=filename)

# %%
#!L
# code.calc_all_metrics(in_norms, out_norms, information=information, filename=filename)

# %%
#!L
code.save_and_bootstrap(experiment_name, in_norms, out_norms, bootstrap_num=100)
# Out:
# bootstrap iter 0! 49500, 29499
# 0.7833123156717176, 0.7043395863395865, 0.6792663658917575, 0.8496017402957873
# bootstrap iter 10! 49500, 29499
# 0.7803219325017352, 0.6978146684233641, 0.672567959025639, 0.8488409101588511
# bootstrap iter 20! 49500, 29499
# 0.7783466291101804, 0.7107262626262627, 0.6734303562931674, 0.8459963880084578
# bootstrap iter 30! 49500, 29499
# 0.7814017585256272, 0.7078535353535353, 0.677102335001156, 0.8481151143244055
# bootstrap iter 40! 49500, 29499
# 0.7798667049490806, 0.6971168831168832, 0.6731140108931732, 0.8487650502881566
# bootstrap iter 50! 49500, 29499
# 0.7789647757277168, 0.7066849446849448, 0.6745199659177554, 0.846754477347052
# bootstrap iter 60! 49500, 29499
# 0.7807363612051907, 0.7019015151515152, 0.6764871240944388, 0.8478738862897951
# bootstrap iter 70! 49500, 29499
# 0.7794811322143774, 0.6992020202020203, 0.6718857077300096, 0.847914977602375
# bootstrap iter 80! 49500, 29499
# 0.7800361275728915, 0.7058540965207633, 0.6737946264103339, 0.8476776000480809
# bootstrap iter 90! 49500, 29499
# 0.781031696674532, 0.7067000439174352, 0.6747712003313763, 0.8478127279154748
# roc-auc: 0.7809062340925099 ± 0.0015144358841227225
# fpr: 0.7032568156106875 ± 0.004974002002914227
# pr_auc_pos: 0.6759102448460516 ± 0.00251807639005467
# pr_auc_neg: 0.8481933416837957 ± 0.0012883443815127319

# %%
#!L
